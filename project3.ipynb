# %% [markdown]
# **بخش اول: پیش پردازش داده ها**
#
# در گام اول، ما عملیات پیش پردازش داده‌ها را بر روی مجموعه داده‌مان اعمال می‌کنیم. ابتدا مجموعه داده مان را فراخوانی می کنیم

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# !gdown 1X76S-596LOf2wtSy2FVMUEC-9s7zk37o
breast_cancer = pd.read_csv('breast cancer.csv')
breast_cancer
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1X76S-596LOf2wtSy2FVMUEC-9s7zk37o
# To: /content/breast cancer.csv
# 100% 125k/125k [00:00<00:00, 90.4MB/s]
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# ...

# %%
breast_cancer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %% [markdown]
# از متد بالا استفاده می‌کنیم، تا اطلاعات مجموعه داده مان رابه دست بیاوریم. باتوجه به مجموعه داده مان، میبینیم که ویژگی
#
# diagnosis
#
# غیرعددی است و مجموعا ۵۶۹ داده داریم. که باقی ویژگی ها از نوع عددی هستند. همچنین هیج داده گمشده ای نداریم
#
#
# ---

# %%
diagnosis = breast_cancer['diagnosis']
encoder = LabelEncoder()
diagnosis_encoded = encoder.fit_transform(diagnosis)
breast_cancer['diagnosis'] = diagnosis_encoded
breast_cancer
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302          1        17.99         10.38          122.80
# 1      842517          1        20.57         17.77          132.90
# 2    84300903          1        19.69         21.25          130.00
# 3    84348301          1        11.42         20.38           77.58
# 4    84358402          1        20.29         14.34          135.10
# ..        ...        ...          ...           ...             ...
# 564    926424          1        21.56         22.39          142.00
# 565    926682          1        20.13         28.25          131.20
# 566    926954          1        16.60         28.08          108.30
# 567    927241          1        20.60         29.33          140.10
# 568     92751          0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# ...

# %% [markdown]
# ما در قسمت بالا ویژگی تشخیص را به مقادیر صحیح صفر و یک تبدیل می کنیم. یک به معنی بدخیم و صفر به معنای خوش خیم است
#
#
# ---

# %%
breast_cancer = breast_cancer.drop(['id','Unnamed: 32'], axis=1)

breast_cancer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    int64
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...

# %% [markdown]
# دو ویژگی
#
# id
# و
# Unnamed: 32
#
# را از مجموعه داده مان حذف می کنیم زیرا تاثیر مهمی در روند مدل سازی ما ندارند همچنین
# همان طور که انتظار داشتیم مقادیر
#
# diagnosis
#
# به مقادیر صحیح تبدیل شده اند، حال ما یک مجموعه داده با ۳۰ ویژگی داریم
#
#
# ---

# %%
from scipy.stats import zscore

# Identify and remove outliers using z-score
z_scores = np.abs(zscore(breast_cancer.iloc[:, 2:]))
threshold = 3

# Find outliers
outlier_indices = np.where(z_scores > threshold)

# Remove outliers
breast_cancer = breast_cancer.drop(breast_cancer.index[outlier_indices[0]])

# Reset the index after removing outliers
breast_cancer = breast_cancer.reset_index(drop=True)

breast_cancer.describe()
# Out:
#         diagnosis  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  495.000000   495.000000    495.000000      495.000000   495.000000
# mean     0.329293    13.868883     18.889778       89.931939   622.613333
# std      0.470432     3.042868      3.966250       20.795084   286.903247
# min      0.000000     6.981000      9.710000       43.790000   143.500000
# 25%      0.000000    11.745000     16.000000       75.475000   424.800000
# 50%      0.000000    13.210000     18.580000       85.630000   538.900000
# 75%      1.000000    15.290000     21.460000      100.250000   718.050000
# max      1.000000    23.270000     30.720000      152.100000  1686.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       495.000000        495.000000      495.000000           495.000000
# mean          0.095075          0.094741        0.074145             0.043306
# ...

# %% [markdown]
# در قسمت بالا با استفاده از استاندارد سازی داده ها، داده های پرت را از مجموعه داده مان تشخیص می دهیم و حذف می کنیم، بنابراین همانطور که در جدول بالا می بینیم در مجموعه داده جدیدمان ۴۹۵ داده داریم.
#
# استفاده می‌کنیم، تا مقادیر اماری مانند میانگین، انحراف معیار، مینیمم، صدک اول، میانه، صدک سوم و ماکسیمم هر ویژگی با مقادیر عددی را به دست اوریم   describe()  از متد
#
#
# ---

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the correlation matrix
correlation_matrix = breast_cancer.iloc[:, 2:].corr()
plt.figure(figsize=(20, 20))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

strong_positive_corr = correlation_matrix[correlation_matrix > 0.7]
strong_negative_corr = correlation_matrix[correlation_matrix < -0.7]

print("Strong Positive Correlations:")
print(strong_positive_corr.stack().drop_duplicates().sort_values(ascending=False))

print("\nStrong Negative Correlations:")
print(strong_negative_corr.stack().drop_duplicates().sort_values(ascending=True))

threshold = 0.5
highly_correlated_features = []
for i in range(len(correlation_matrix.columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i, j]) > threshold:
            feature_i = correlation_matrix.columns[i]
            feature_j = correlation_matrix.columns[j]
            highly_correlated_features.append((feature_i, feature_j))

# Extract the selected features
selected_features = set()
for feature_i, feature_j in highly_correlated_features:
    selected_features.add(feature_i)
    selected_features.add(feature_j)

selected_data = breast_cancer[list(selected_features) + ['diagnosis']]
selected_data.info()
# Out:
# Strong Positive Correlations:
# texture_mean         texture_mean       1.000000
# radius_worst         perimeter_worst    0.994003
# perimeter_mean       area_mean          0.990969
# radius_worst         area_worst         0.990649
# perimeter_worst      area_worst         0.984433
#                                           ...
# radius_se            perimeter_worst    0.715553
# concave points_mean  perimeter_se       0.714403
# concavity_mean       area_se            0.708938
# concave points_mean  radius_se          0.706778
# perimeter_se         radius_worst       0.703428
# Length: 69, dtype: float64
#
# Strong Negative Correlations:
# Series([], dtype: float64)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 495 entries, 0 to 494
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   area_mean                495 non-null    float64
# ...

# %% [markdown]
# با استفاده از
#
# correlation matrix
#
# یک نمودار حرارتی از ماتریس همبستگی می توانیم مشاهده کنیم که یک نمایش بصری از همبستگی ها را ارائه می دهد. این به ما این امکان را می دهد تا به سرعت همبستگی ها و الگوهای قوی و ضعیف را شناسایی کنیم. می دانیم درصورت داشتن همبستگی مثبت یک رابطه خطی و در صورت وجود همبستگی منفی یک رابطه معکوس داریم. همچنین می دانیم که این بازه بین ۱ تا ۱- متغیر است و هرچه قدر به انتها و ابتدا بازه نزدیک باشند، قوی بودن و هرچه از ابتدا و انتها دور باشند ضعیف بودن ان، شدت می گیرد. همچنین سلول های فردی در نمودار حرارتی  که از الگوی اطراف متمایز هستند، می توانند نقاط دورافتاده بالقوه یا روابط غیرعادی بین متغیرهای خاص را نشان دهند. در ادامه کد،
# ویژگی هایی که با هم همبستگی زیادی دارند انتخاب می کنیم و آن ها را نگه میداریم و ان هایی که همبستگی ندارند را حذف می کنیم، که قسمت بالا نشان می دهد ۲۶ ویژگی داریم که این شرط برایشان صادق است
#
#
# ---

# %% [markdown]
# **بخش دوم: مدل سازی**

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

values = selected_data.drop(labels='diagnosis',axis=1)
target = selected_data.diagnosis

# Split the dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(values, target, test_size=0.2)

# Perform feature scaling
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ابتدا ویژگی ها و متغیر هدف را از هم جدا می کنیم و سپس مجموعه داده مان را به نسبت ۸۰ به ۲۰ به مجموعه داده اموزشی و مجموعه داده تست تقسیم می کنیم، سپس ویژگی های مجموعه داده اموزشی و تست را مقیاس بندی می کنیم. این گام مقیاس بندی ویژگی ها، مهمترین قسمت در الگوریتم های یادگیری ماشین است. درواقع می توانیم بگوییم مقادیر ویژگی ها را نرمال سازی می کنیم زیرا در غیر این صورت ویژگی‌هایی با مقیاس‌های بسیار متفاوت می‌توانند منجر به مدل سازی مغرضانه شوند، به عنوان مثال ویژگی‌هایی با مقیاس‌های بزرگ‌تر ممکن است بر فرآیند یادگیری تسلط پیدا کنند. همچنین مقیاس بندی ویژگی ها می تواند سرعت همگرایی و پایداری الگوریتم بهینه سازی را در طول فرآیند آموزش، بهبود ببخشد. مقادیر بزرگ ویژگی ها گاهی اوقات می تواند باعث بی ثباتی عددی در محاسبات بشود. به عنوان مثال، در شبکه‌های عصبی، مقادیر ورودی بزرگ می‌تواند به اشباع توابع فعال‌سازی منجر شود و در نتیجه گرادیان‌ها بسیار کوچک شوند. مقیاس‌بندی ویژگی‌ها به جلوگیری از چنین بی‌ثباتی عددی کمک می‌کند و محاسبات نرم‌تر را در طول آموزش تضمین می‌کند. همچنین مقیاس گذاری تضمین می کند که به همه ویژگی ها در فرآیند یادگیری اهمیت یکسانی داده می شود.

# %%
# Build the MLP model
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model with validation split
model.fit(X_train, y_train, epochs=10, batch_size=32, verbose=1, validation_split=0.2)

# Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test, y_test)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# Epoch 1/10
# 10/10 [==============================] - 1s 22ms/step - loss: 0.5837 - accuracy: 0.7373 - val_loss: 0.4139 - val_accuracy: 0.9375
# Epoch 2/10
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3135 - accuracy: 0.9272 - val_loss: 0.2686 - val_accuracy: 0.9375
# Epoch 3/10
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2126 - accuracy: 0.9335 - val_loss: 0.2020 - val_accuracy: 0.9375
# Epoch 4/10
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1682 - accuracy: 0.9462 - val_loss: 0.1648 - val_accuracy: 0.9375
# Epoch 5/10
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1407 - accuracy: 0.9557 - val_loss: 0.1408 - val_accuracy: 0.9375
# Epoch 6/10
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1236 - accuracy: 0.9652 - val_loss: 0.1225 - val_accuracy: 0.9500
# Epoch 7/10
# ...

# %% [markdown]
# این مدل با استفاده :MLPمدل
#
#  TensorFlow
#  از
# Sequential()
#
# ایجاد شده است. که شامل سه لایه است: از دو لایه پنهان، ۶۴ نورون و تابع
# فعالساز
#
# RELU
#
# و یک لایه خروجی شامل یک نورون و تابع فعالساز
#
#  sigmoid
#
#  تشکیل شده است
#
# همچنین لایه ورودی جایی است که مدل، داده های ورودی را دریافت می کند و آن را برای پردازش به لایه های بعدی ارسال می کند. تعداد نورون ها در لایه ورودی با شکل داده های ورودی تعیین می شود. در اینجا، تعداد نورون ها در لایه ورودی با تعداد ویژگی های مجموعه داده برابر است که همان
#
# X_train.shape[1]
#
# است
#
# بعد از مدل سازی، مدل را کامپایل می کنیم. تا مراحل اموزش را پیکربندی کنیم. در این گام ما می خواهیم وزن های شبکه عصبی را در طول اموزش به طوره بهینه به روز رسانی کنیم. که اینجا از بهینه ساز
#
# ‌adam
#
# استفاده کرده ایم. این الگوریتم بهینه سازی به صورت پویا نرخ یادگیری را برای هر پارامتر در طول آموزش تنظیم می کند. نرخ های یادگیری را بر اساس گرادیان های گذشته محاسبه می کند و نرخ یادگیری جداگانه ای را برای هر پارامتر ذخیره می کند. این سازگاری به همگرایی سریعتر و یادگیری کارآمد کمک می کند. همچنین تصحیح جهت گیری را برای تخمین لحظه های اول و دوم گرادیان اعمال می کند. این تصحیح در مراحل اولیه آموزش، زمانی که برآوردها به دلیل مقداردهی اولیه مغرضانه هستند کمک می کند. دقت تخمین ها را بهبود می بخشد و به تثبیت فرآیند بهینه سازی کمک می کند.
#
# سپس از تابع اتلاف در جهت کمینه کردن تفاوت بین خروجی پیش‌بینی‌شده یک مدل و خروجی  مرتبط با یک ورودی داده شده استفاده می کنیم. که در اینجا از
#
# binary_crossentropy
#
# استفاده کرده ایم. که تفاوت بین احتمالات پیش بینی شده و برچسب های باینری واقعی را کمینه می کند. اندازه گیری می کند که چقدر احتمالات پیش بینی شده با برچسب های واقعی مطابقت دارند و مدل را برای پیش بینی های نادرست
#
# penalizing
#
#  می کند. همچنین با استفاده از
#
#  metrics=['accuracy']
#
#  دقت مدل را بررسی می کنیم. با این کار، مدل، معیار دقت را به عنوان بخشی از پیشرفت آموزش و نتایج ارزیابی نمایش می‌دهد. این به ما کمک می کند عملکرد مدل را نظارت کنیم و دقت طبقه بندی آن را ارزیابی کنیم. سپس از
#
#
# validation_split
#
#
#  برای تعیین بخشی از داده های آموزشی در جهت اعتبار سنجی، که در طول فرآیند آموزش کنار گذاشته می شوند، استفاده می کنیم. این روش برای ارزیابی عملکرد مدل و نظارت بر توانایی تعمیم آن است. در این قسمت ما تعداد تکرار برای مدلی که اموزش داده می شود را ۱۰ گذاشته ایم که همان تعداد عبور از همه سطرها در مجموعه داده آموزش است. تعداد نمونه ها بر هر مقدار به روز رسانی شده گرادیان
#  را روی ۳۲ گذاشته ایم
#
#  verbose=1
#
#  گویا بودن فرایند اموزشی را کنترل می کند. و نوار پیشرفت برای هر تکرار در خروجی رانشان می دهد.
#
#
#  validation_split=0.2
#
# کسری از داده های آموزشی را که باید برای اعتبارسنجی استفاده شود را مشخص می کند. در این صورت ۲۰ درصد از داده های آموزشی برای اعتبارسنجی در طول آموزش ذخیره می شود. در نهایت مدل را برای مجموعه داده تست، ارزیابی می کنیم
#
#
# ---

# %% [markdown]
# **بخش سوم: مقایسه استفاده از هایپر پارامترهای مختلف و گزارش نتایح آن**

# %% [markdown]
# مدل اول: نرخ یادیگیری برابر با ۰.۰۰۱

# %%
# Build the MLP model
model_lr_1 = tf.keras.models.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Compile the model
learning_rate_1 = 0.001
optimizer_1 = tf.keras.optimizers.Adam(learning_rate=learning_rate_1)
model_lr_1.compile(optimizer=optimizer_1, loss='binary_crossentropy', metrics=['accuracy'])

# Train the model with validation split
model_lr_1.fit(X_train, y_train, epochs=10, batch_size=32, verbose=1, validation_split=0.2)

# Evaluate the model on the test set
loss_1, accuracy_1 = model_lr_1.evaluate(X_test, y_test)
print("Test Loss:", loss_1)
print("Test Accuracy:", accuracy_1)
# Out:
# Epoch 1/10
# 10/10 [==============================] - 1s 24ms/step - loss: 0.5061 - accuracy: 0.8006 - val_loss: 0.3781 - val_accuracy: 0.9125
# Epoch 2/10
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2940 - accuracy: 0.9304 - val_loss: 0.2434 - val_accuracy: 0.9375
# Epoch 3/10
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2012 - accuracy: 0.9367 - val_loss: 0.1742 - val_accuracy: 0.9500
# Epoch 4/10
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1530 - accuracy: 0.9430 - val_loss: 0.1314 - val_accuracy: 0.9625
# Epoch 5/10
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1234 - accuracy: 0.9620 - val_loss: 0.1072 - val_accuracy: 0.9625
# Epoch 6/10
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1041 - accuracy: 0.9715 - val_loss: 0.0917 - val_accuracy: 0.9750
# Epoch 7/10
# ...

# %% [markdown]
# مدل دوم: نرخ یادیگیری برابر با ۰.۰۱

# %%
# Build the MLP model
model_lr_2 = tf.keras.models.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Compile the model
learning_rate_2 = 0.001
optimizer_2 = tf.keras.optimizers.Adam(learning_rate=learning_rate_2)
model_lr_2.compile(optimizer=optimizer_2, loss='binary_crossentropy', metrics=['accuracy'])

# Train the model with validation split
model_lr_2.fit(X_train, y_train, epochs=10, batch_size=32, verbose=1, validation_split=0.2)

# Evaluate the model on the test set
loss_2, accuracy_2 = model_lr_2.evaluate(X_test, y_test)
print("Test Loss:", loss_2)
print("Test Accuracy:", accuracy_2)
# Out:
# Epoch 1/10
# 10/10 [==============================] - 1s 24ms/step - loss: 0.5388 - accuracy: 0.7405 - val_loss: 0.4194 - val_accuracy: 0.8625
# Epoch 2/10
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3389 - accuracy: 0.9367 - val_loss: 0.2706 - val_accuracy: 0.9125
# Epoch 3/10
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2247 - accuracy: 0.9430 - val_loss: 0.1862 - val_accuracy: 0.9375
# Epoch 4/10
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1647 - accuracy: 0.9589 - val_loss: 0.1414 - val_accuracy: 0.9375
# Epoch 5/10
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1288 - accuracy: 0.9684 - val_loss: 0.1132 - val_accuracy: 0.9625
# Epoch 6/10
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1081 - accuracy: 0.9747 - val_loss: 0.0924 - val_accuracy: 0.9625
# Epoch 7/10
# ...

# %% [markdown]
# مدل سوم
#
# epochs = ۱۰

# %%
# Build the MLP model
modelـepochs_1 = tf.keras.models.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Compile the model
modelـepochs_1.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model with validation split
modelـepochs_1.fit(X_train, y_train, epochs=10, batch_size=32, verbose=1, validation_split=0.2)

# Evaluate the model on the test set
loss_3, accuracy_3 = modelـepochs_1.evaluate(X_test, y_test)
print("Test Loss:", loss_3)
print("Test Accuracy:", accuracy_3)
# Out:
# Epoch 1/10
# 10/10 [==============================] - 1s 25ms/step - loss: 0.4716 - accuracy: 0.8956 - val_loss: 0.3700 - val_accuracy: 0.9250
# Epoch 2/10
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2853 - accuracy: 0.9304 - val_loss: 0.2410 - val_accuracy: 0.9500
# Epoch 3/10
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1947 - accuracy: 0.9367 - val_loss: 0.1757 - val_accuracy: 0.9375
# Epoch 4/10
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1497 - accuracy: 0.9494 - val_loss: 0.1395 - val_accuracy: 0.9375
# Epoch 5/10
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1244 - accuracy: 0.9652 - val_loss: 0.1149 - val_accuracy: 0.9500
# Epoch 6/10
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1063 - accuracy: 0.9715 - val_loss: 0.1020 - val_accuracy: 0.9625
# Epoch 7/10
# ...

# %% [markdown]
# مدل چهارم
#
# epochs = ۲۰

# %%
# Build the MLP model
modelـepochs_2 = tf.keras.models.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Compile the model
modelـepochs_2.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model with validation split
modelـepochs_2.fit(X_train, y_train, epochs=20, batch_size=32, verbose=1, validation_split=0.2)

# Evaluate the model on the test set
loss_4, accuracy_4 = modelـepochs_2.evaluate(X_test, y_test)
print("Test Loss:", loss_4)
print("Test Accuracy:", accuracy_4)
# Out:
# Epoch 1/20
# 10/10 [==============================] - 1s 22ms/step - loss: 0.7132 - accuracy: 0.5380 - val_loss: 0.5068 - val_accuracy: 0.8875
# Epoch 2/20
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3900 - accuracy: 0.9304 - val_loss: 0.3168 - val_accuracy: 0.9375
# Epoch 3/20
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2530 - accuracy: 0.9367 - val_loss: 0.2190 - val_accuracy: 0.9375
# Epoch 4/20
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1808 - accuracy: 0.9430 - val_loss: 0.1629 - val_accuracy: 0.9500
# Epoch 5/20
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1433 - accuracy: 0.9620 - val_loss: 0.1261 - val_accuracy: 0.9750
# Epoch 6/20
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1197 - accuracy: 0.9684 - val_loss: 0.1003 - val_accuracy: 0.9875
# Epoch 7/20
# ...

# %%
# Print the accuracy of each model
print("Model 1 Accuracy:", accuracy_1 , "Model 1 Loss:", loss_1)
print("Model 2 Accuracy:", accuracy_2 , "Model 2 Loss:", loss_2)
print("Model 3 Accuracy:", accuracy_3 , "Model 3 Loss:", loss_3)
print("Model 4 Accuracy:", accuracy_4 , "Model 4 Loss:", loss_4)
# Out:
# Model 1 Accuracy: 0.9898989796638489 Model 1 Loss: 0.05878074839711189
# Model 2 Accuracy: 0.9898989796638489 Model 2 Loss: 0.05039302632212639
# Model 3 Accuracy: 0.9797979593276978 Model 3 Loss: 0.060893505811691284
# Model 4 Accuracy: 0.9797979593276978 Model 4 Loss: 0.04196031019091606

# %% [markdown]
# باتوجه به مقادیر
#
# Accuracy
#
# برای هر مدل، مدل اول و دوم بیشترین مقدار را دارند که از بین این دو مدل،  مدل دوم مقدار
#
# Loss
#
# کمتری را دارد نشان می دهد،که مدل بهتری است. همچنین می توان گفت زمانی که نرخ یادگیری بیشتر شده باشد و یا زمانی که
#
# epoch
#
# بیشتر شده باشد، مدل کارامدتر است. به عنوان مثال در مدل دوم و چهارم می بینیم که مقدار
#
#
# Loss
#
#
# کاهش پیدا کرده است که پارامتر مهمی در ارزیابی مدل است.
# همچنین نرخ یادگیری تاثیر مهمی در کارامدی مدل دارد. در حالت کلی انتخاب تعداد دوره‌ها مستلزم یافتن تعادل بین عدم تناسب و بیش‌برازش است و انتخاب نرخ یادگیری مستلزم یافتن تعادل مناسب بین سرعت همگرایی و پایداری است. بنابراین همیشه توصیه می شود که با نرخ یادگیری متوسط شروع کنیم و آن را بر اساس پیشرفت آموزش و رفتار مشاهده شده مدل تنظیم کنیم.
#
#
# ---

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

y_pred_prob = model_lr_2.predict(X_test)
threshold = 0.5
y_pred = np.where(y_pred_prob >= threshold, 1, 0)

# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# Calculate evaluation metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print()
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
print()
# Out:
# 4/4 [==============================] - 0s 5ms/step
# Accuracy: 0.98989898989899
# Precision: 0.9666666666666667
# Recall: 1.0
# F1-score: 0.983050847457627

# %% [markdown]
# *    precision
#
# برای هر کلاس نرخ نسبت مثبت های واقعی پیش بینی شده به کل مثبت های پیش بینی شده را بیان می کند، برابر است با
#
# Precision: 0.96
#
# که نشان می دهد حدود ۹۶.۶۶ درصد از مواردی که به عنوان مثبت پیش بینی شده اند، در واقع مثبت واقعی هستند.
#
# *    Recall
#
# برای هر کلاس نرخ نسبت پیش بینی مثبت های واقعی به کل مثبت های واقعی را نشان می دهد. برابر است با
#
# Recall: 1.0
#
# این مقدار نشان دهنده توانایی مدل در شناسایی صحیح موارد مثبت است. ۱۰۰ درصد فراخوان  به این معنی است که مدل تمام موارد مثبت واقعی را به درستی شناسایی کرده است.
#
# *    F1-Score
#
# برای هر کلاس، میانگین هارمونیک دو معیار دقت و یادآوری را محاسبه می کند. یک متر واحد را ارائه می دهد که دقت و یادآوری را متعادل کند. برابر است با
#
# F1-score: 0.98
#
# که نشان دهنده تعادل خوبی بین دقت و فراخوان است.
#
# *     Accuracy
#
# نشان دهنده دقت کلی مدل طبقه بندی کننده است. نسبت نمونه هایی است که به درستی طبقه بندی شده اند به تعداد کل نمونه ها را نشان می دهد، برابر است با
#
# Accuracy: 0.98
#
#
# که به این معنی است که تقریباً ۹۸.۹۹ درصد از پیش بینی های انجام شده توسط مدل صحیح است.
#
# ---
